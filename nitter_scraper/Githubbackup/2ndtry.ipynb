# %%
# Step 1: Imports
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from scipy.stats import entropy  # For noise measurement
import re

# Load data from Sheet2 (assume same file; adjust path if needed)
df = pd.read_excel('tweet_market_impact_new.xlsx', sheet_name='Sheet2', header=0)

# Sort by timestamp for sequential analysis
df = df.sort_values('Timestamp').reset_index(drop=True)  # Assume 'Timestamp' column

# Clean text if not already (remove links, etc.)
df['Tweet_clean'] = df['Tweet'].apply(lambda x: re.sub(r'http\S+|www\S+', '', str(x)).strip())

print("Data Loaded and Sorted. Shape:", df.shape)
df.head()
# Out:
# Data Loaded and Sorted. Shape: (162, 33)
#    tweet_ID           Timestamp Twitter_acc  \
# 0     13662 2025-06-12 17:41:00  WhiteHouse
# 1      3791 2025-06-12 17:48:00  mfa_russia
# 2      7807 2025-06-12 17:51:00  WhiteHouse
# 3      4387 2025-06-12 17:54:00  mfa_russia
# 4      3902 2025-06-12 17:55:00  WhiteHouse
#
#                                                Tweet  Mid_Open_Execution  \
# 0  MAKE AMERICA WEALTHY AGAIN 💸\n\nPresident Trum...              68.000
# 1  Honour the Past. Embrace the Future\n✍️Article...              67.855
# 2  HAPPENING NOW: @Sec_Noem hosts a press confere...              67.875
# 3  🎊The Embassy of Russia in South Africa hosted ...              67.905
# 4  With @POTUS' economic plan, we’ll deliver seri...              67.955
#
#    Execution_Delayed  MI_1min_MidOpen  MI_1min_MidClose  MI_5min_MidOpen  \
# 0              False         2.941176         -2.941176       -11.764706
# 1              False         3.684327          4.421192         2.947461
# 2              False         0.000000         -1.473297        19.889503
# 3              False         7.363228         15.462779        48.597305
# 4              False         8.093591         19.866088        36.789052
#
#    MI_5min_MidClose  ...  MI_12h_MidClose  MI_1d_MidOpen  MI_1d_MidClose  \
# 0        -18.382353  ...       947.794118     623.529412      612.500000
# 1          7.368654  ...       903.396949     625.598703      620.440645
# 2         31.675875  ...       895.027624     609.208103      620.994475
# 3         44.179368  ...       871.069877     605.993668      607.466313
# 4         34.581708  ...       838.054595     598.925760      608.490913
#
#    MI_2d_MidOpen  MI_2d_MidClose  MI_3d_MidOpen  MI_3d_MidClose  \
# 0    1302.205882     1256.617647    1302.205882     1256.617647
# 1    1326.357674     1280.672021    1326.357674     1280.672021
# 2    1323.020258     1277.348066    1323.020258     1277.348066
# 3    1318.017819     1272.365805    1318.017819     1272.365805
# 4    1309.690236     1264.071812    1309.690236     1264.071812
#
#    MI_4d_MidOpen  MI_4d_MidClose  \
# 0     527.941176      524.264706
# 1     565.175742      557.070223
# 2     571.639042      574.585635
# 3     570.650173      577.277078
# 4     568.758737      576.116548
#
#                                          Tweet_clean
# 0  MAKE AMERICA WEALTHY AGAIN 💸\n\nPresident Trum...
# 1  Honour the Past. Embrace the Future\n✍️Article...
# 2  HAPPENING NOW: @Sec_Noem hosts a press confere...
# 3  🎊The Embassy of Russia in South Africa hosted ...
# 4  With @POTUS' economic plan, we’ll deliver seri...
#
# [5 rows x 33 columns]

# %%
# Step 2: Define oil-related keywords and topic detection
oil_keywords = ['Explosions', 'Tehran', 'Israel', 'Missile', 'Strike', 'WTI', 'oil', 'crude', 'energy', 'Iran', 'nuclear', 'Trump', 'Netanyahu']  # Expanded for better detection

# Function to flag oil-related tweets
def is_oil_topic(text):
    return any(word.lower() in text.lower() for word in oil_keywords)

df['is_oil_topic'] = df['Tweet_clean'].apply(is_oil_topic)

# ML Topic Modeling: Use TF-IDF + KMeans for clustering topics over time
vectorizer = TfidfVectorizer(lowercase=False, stop_words='english', max_features=200, min_df=1)
tfidf_matrix = vectorizer.fit_transform(df['Tweet_clean'])

# Cluster into topics (e.g., 5 clusters; adjust based on data)
kmeans = KMeans(n_clusters=5, random_state=42)
df['topic_cluster'] = kmeans.fit_predict(tfidf_matrix)

# Alternative: LDA for probabilistic topics
lda = LDA(n_components=5, random_state=42)
lda_topics = lda.fit_transform(tfidf_matrix)
df['lda_topic'] = np.argmax(lda_topics, axis=1)  # Dominant topic

print("Topic Detection Complete.")
df[['Tweet_clean', 'is_oil_topic', 'topic_cluster', 'lda_topic']].head(10)
# Out:
# Topic Detection Complete.
#                                          Tweet_clean  is_oil_topic  \
# 0  MAKE AMERICA WEALTHY AGAIN 💸\n\nPresident Trum...          True
# 1  Honour the Past. Embrace the Future\n✍️Article...         False
# 2  HAPPENING NOW: @Sec_Noem hosts a press confere...         False
# 3  🎊The Embassy of Russia in South Africa hosted ...         False
# 4  With @POTUS' economic plan, we’ll deliver seri...         False
# 5  🚨 From the National Association of Manufacture...         False
# 6  🗣️ "It is already clear that energy efficiency...          True
# 7                                          TAKE POLL         False
# 8  Donald J. Trump Truth Social 06.12.25 02:03 PM...          True
# 9  AMERICA’S FRANCHISED DEALERS APPLAUD PRESIDENT...          True
#
#    topic_cluster  lda_topic
# 0              4          2
# 1              2          2
# 2              0          3
# 3              2          2
# 4              4          2
# 5              4          1
# 6              0          3
# 7              0          0
# 8              0          0
# 9              0          2

# %%
# Step 3: Sequential Analysis as Data Feed
# Cumulative tracking: Scan tweet by tweet, track accounts per topic
df['cumulative_oil_accounts'] = 0
df['current_topic_accounts'] = ''

# Dictionary to track accounts per topic (use cluster or LDA)
topic_accounts = {}  # topic: set of accounts

for idx, row in df.iterrows():
    topic = row['lda_topic']  # Or 'topic_cluster'
    acc = row['Twitter_acc']
    
    if row['is_oil_topic']:
        if topic not in topic_accounts:
            topic_accounts[topic] = set()
        topic_accounts[topic].add(acc)
        
        df.at[idx, 'cumulative_oil_accounts'] = len(topic_accounts[topic])
        df.at[idx, 'current_topic_accounts'] = ', '.join(topic_accounts[topic])
    
    # Reset if narrative shift (e.g., new day or logic for shift; simplify here)

# Trade entry: Where cumulative >=5
trade_entries = df[df['cumulative_oil_accounts'] >= 5]

print("Trade Entry Points (>=5 Accounts on Oil Topic):")
display(trade_entries[['Timestamp', 'Twitter_acc', 'Tweet_clean', 'cumulative_oil_accounts', 'current_topic_accounts', 'lda_topic']])

# Plot cumulative accounts over time
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['cumulative_oil_accounts'], marker='o')
plt.axhline(y=5, color='r', linestyle='--', label='Trade Entry Threshold')
plt.title('Cumulative Accounts on Oil Topics Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Cumulative Accounts')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Trade Entry Points (>=5 Accounts on Oil Topic):
#               Timestamp      Twitter_acc  \
# 42  2025-06-12 19:54:00   Yemenimilitary
# 47  2025-06-12 20:48:00           chigrl
# 62  2025-06-12 23:14:00       WhiteHouse
# 68  2025-06-13 00:07:00        IntelDoge
# 72  2025-06-13 00:20:00  TrumpDailyPosts
# 75  2025-06-13 00:21:00           chigrl
# 76  2025-06-13 00:22:00       WhiteHouse
# 77  2025-06-13 00:22:00            POTUS
# 78  2025-06-13 00:25:00        IntelDoge
# 82  2025-06-13 00:44:00           chigrl
# 84  2025-06-13 00:45:00        IntelDoge
# 85  2025-06-13 00:46:00        IntelDoge
# 90  2025-06-13 01:00:00              IDF
# 91  2025-06-13 01:00:00       WhiteHouse
# 92  2025-06-13 01:00:00            POTUS
# 96  2025-06-13 01:05:00        IsraeliPM
# 99  2025-06-13 01:17:00        IntelDoge
# 101 2025-06-13 01:19:00     SStapczynski
# 104 2025-06-13 01:41:00        IntelDoge
# 105 2025-06-13 01:42:00        IntelDoge
# 114 2025-06-13 02:06:00        IntelDoge
# 116 2025-06-13 02:07:00        IntelDoge
# 124 2025-06-13 02:26:00     SStapczynski
# 125 2025-06-13 02:27:00        IntelDoge
# 126 2025-06-13 02:31:00        IntelDoge
# 128 2025-06-13 02:36:00        IntelDoge
# 132 2025-06-13 02:40:00     SStapczynski
# 136 2025-06-13 02:50:00     SStapczynski
# 137 2025-06-13 02:51:00        IntelDoge
# 138 2025-06-13 02:52:00        IntelDoge
# 139 2025-06-13 02:56:00        IntelDoge
# 140 2025-06-13 02:58:00  IRIran_Military
# 141 2025-06-13 03:00:00        IntelDoge
# 142 2025-06-13 03:00:00  IRIran_Military
# 143 2025-06-13 03:01:00        IntelDoge
# 146 2025-06-13 03:05:00        IntelDoge
# 148 2025-06-13 03:11:00  IRIran_Military
# 152 2025-06-13 03:23:00  IRIran_Military
# 157 2025-06-13 03:32:00        IntelDoge
# 159 2025-06-13 03:37:00  TrumpDailyPosts
# 160 2025-06-13 03:41:00              IDF
# 161 2025-06-13 03:41:00        IntelDoge
#
#                                            Tweet_clean  \
# 42   In an article by the editor-in-chief of Haaret...
# 47   If you missed Catherine Yoshimoto from\n@FTSER...
# 62   President Trump and the First Lady Participate...
# 68   #Israel's Minister of Defense, Israel Katz, ha...
# 72           President Trump News Community - BREAKING
# 75              WTI hits 72.30 on @#$@ is getting real
# 76   AMERICA FIRST — Chants of ‘USA’ rang out loud ...
# 77   AMERICA FIRST — Chants of ‘USA’ rang out loud ...
# 78   Trump convening cabinet level meeting shortly,...
# 82   Not saying you should pay any attention to Nin...
# 84   Israel warning of potential incoming ballistic...
# 85   BREAKING: #IDF confirms preemptive airstrikes ...
# 90   A statement from IDF Spokesperson BG Effie Def...
# 91   Statement from Secretary of State Marco Rubio\...
# 92   Statement from Secretary of State Marco Rubio\...
# 96   Prime Minister Netanyahu:\n"Moments ago, Israe...
# 99   Rumors circulating that the house of Fereydoon...
# 101  Brent oil surges above 8% after Israel carries...
# 104       Iranian air force jets spotted over #Tehran.
# 105  Iran's air force will not be partaking in reta...
# 114  Donald Trump to hold a meeting in the situatio...
# 116  Iranian state TV says "no signs of contaminati...
# 124  Brent oil futures now up more than 9% after Is...
# 125  #Israel'i source to Fox News, "This is just th...
# 126  New target assassination claim.\n\nIn Iran, it...
# 128  In case it is not painfully obvious, I would n...
# 132                 BRENT OIL BRIEFLY UP MORE THAN 13%
# 136  Oil futures are at the highest level since Jan...
# 137  #Israel'i airliners flying empty planes out of...
# 138  Israel pushing HARD that they fully cooperated...
# 139  Iranian air defenses activated in Tehran. New ...
# 140  Zionist terrorists have massacred civilians in...
# 141  As others have mentioned, it absolutely feels ...
# 142  The spokesperson for the Armed Forces’ General...
# 143  Areas around the oil refinery in Tabriz have b...
# 146  Statement out from #Iran's Supreme Leader Ali ...
# 148  An important message from the Leader of the Is...
# 152  In the Name of God, the Compassionate, the Mer...
# 157  The "Wings of Zion", a Boeing 767-338ER respon...
# 159          President Trump News Community - BREAKING
# 160  𝗗𝗘𝗖𝗟𝗔𝗦𝗦𝗜𝗙𝗜𝗘𝗗: 𝗜𝗿𝗮𝗻’𝘀 𝗡𝘂𝗰𝗹𝗲𝗮𝗿 𝗣𝗹𝗮𝗻𝘀\n\nRecent i...
# 161  Wings of Zion aircraft now circling off the co...
#
#      cumulative_oil_accounts  \
# 42                         5
# 47                         6
# 62                         6
# 68                         7
# 72                         7
# 75                         7
# 76                         7
# 77                         8
# 78                         8
# 82                         8
# 84                         8
# 85                         5
# 90                         9
# 91                         6
# 92                         7
# 96                         9
# 99                         9
# 101                       10
# 104                        7
# 105                       10
# 114                       10
# 116                       10
# 124                       10
# 125                       10
# 126                        7
# 128                        7
# 132                        8
# 136                       10
# 137                       10
# 138                       10
# 139                        8
# 140                        9
# 141                       10
# 142                        9
# 143                       10
# 146                        9
# 148                        9
# 152                        9
# 157                       10
# 159                       10
# 160                        9
# 161                       10
#
#                                 current_topic_accounts  lda_topic
# 42   Yemenimilitary, WhiteHouse, TrumpDailyPosts, I...          2
# 47   Yemenimilitary, WhiteHouse, chigrl, TrumpDaily...          2
# 62   Yemenimilitary, WhiteHouse, chigrl, TrumpDaily...          2
# 68   Yemenimilitary, WhiteHouse, chigrl, TrumpDaily...          2
# 72   Yemenimilitary, WhiteHouse, chigrl, TrumpDaily...          2
# 75   Yemenimilitary, WhiteHouse, chigrl, TrumpDaily...          2
# 76   Yemenimilitary, WhiteHouse, chigrl, TrumpDaily...          2
# 77   Yemenimilitary, WhiteHouse, chigrl, POTUS, Tru...          2
# 78   Yemenimilitary, WhiteHouse, chigrl, POTUS, Tru...          2
# 82   Yemenimilitary, WhiteHouse, chigrl, POTUS, Tru...          2
# 84   Yemenimilitary, WhiteHouse, chigrl, POTUS, Tru...          2
# 85              IDF, chigrl, IEA, IsraeliPM, IntelDoge          3
# 90   IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 91   IDF, WhiteHouse, chigrl, IEA, IsraeliPM, Intel...          3
# 92   IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 96   IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 99   IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 101  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 104  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 105  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 114  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 116  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 124  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 125  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 126  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 128  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 132  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 136  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 137  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 138  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 139  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 140  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 141  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 142  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 143  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 146  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 148  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 152  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 157  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 159  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2
# 160  IDF, WhiteHouse, chigrl, IEA, POTUS, IsraeliPM...          3
# 161  IDF, Yemenimilitary, WhiteHouse, chigrl, POTUS...          2

# %%
# Step 4: Narrative Shift Detection (Noise Reduction)
# Measure noise: Word diversity (entropy) in rolling windows
window_size = 20  # Tweets per window; adjust
df['word_diversity'] = 0.0

for i in range(len(df)):
    start = max(0, i - window_size + 1)
    window_text = ' '.join(df['Tweet_clean'].iloc[start:i+1])
    words = window_text.split()
    if words:
        word_counts = pd.Series(words).value_counts(normalize=True)
        df.at[i, 'word_diversity'] = entropy(word_counts)  # High entropy = high noise/diversity

# Shift point: Where diversity drops significantly (e.g., below mean - std)
mean_div = df['word_diversity'].mean()
std_div = df['word_diversity'].std()
shift_points = df[df['word_diversity'] < (mean_div - std_div)]

print("Narrative Shift Points (Low Noise):")
display(shift_points[['Timestamp', 'Tweet_clean', 'word_diversity', 'lda_topic']])

# Plot diversity over time
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['word_diversity'], color='b')
plt.axhline(y=mean_div - std_div, color='r', linestyle='--', label='Shift Threshold')
plt.title('Narrative Noise (Word Diversity) Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Entropy (Diversity)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Narrative Shift Points (Low Noise):
#               Timestamp                                        Tweet_clean  \
# 0   2025-06-12 17:41:00  MAKE AMERICA WEALTHY AGAIN 💸\n\nPresident Trum...
# 1   2025-06-12 17:48:00  Honour the Past. Embrace the Future\n✍️Article...
# 2   2025-06-12 17:51:00  HAPPENING NOW: @Sec_Noem hosts a press confere...
# 3   2025-06-12 17:54:00  🎊The Embassy of Russia in South Africa hosted ...
# 4   2025-06-12 17:55:00  With @POTUS' economic plan, we’ll deliver seri...
# 5   2025-06-12 18:00:00  🚨 From the National Association of Manufacture...
# 79  2025-06-13 00:25:00  In the name of God, the Most Gracious, the Mos...
# 81  2025-06-13 00:43:00  #Israel'i media outlet @kann_news, quoting sec...
# 112 2025-06-13 01:56:00  Absolutely insane scenes we're witnessing righ...
# 121 2025-06-13 02:21:00  Another wave of airstrikes underway according ...
# 122 2025-06-13 02:23:00  Certain Iranian media outlets denying the deat...
# 123 2025-06-13 02:25:00        نَصْرٌ مِّن اللَّهِ وَفَتْحٌ قَرِيبٌ 🇵🇸🇾🇪🇮🇷
#
#      word_diversity  lda_topic
# 0          3.204778          2
# 1          4.422581          2
# 2          4.586124          3
# 3          4.798012          2
# 4          5.002544          2
# 5          5.102623          1
# 79         5.054967          3
# 81         5.079278          1
# 112        5.118837          3
# 121        5.119862          4
# 122        5.073453          1
# 123        5.074301          0

# %%
# Step 5: Integrate with Market Impact (MI Diffs from Baseline)
# Assume MI columns exist; compute diffs as before (move this earlier to ensure columns are created)
intervals = ['1min', '5min', '15min', '30min', '1h', '2h', '4h', '8h', '12h', '1d', '2d', '3d', '4d']
df['MI_Baseline'] = df.get('MI_1min_MidOpen', pd.Series(0, index=df.index))  # Fallback if missing
for interval in intervals[1:]:
    open_col = f'MI_{interval}_MidOpen'
    if open_col in df.columns:
        df[f'MI_{interval}_FromBaseline'] = df[open_col] - df['MI_Baseline']
    else:
        df[f'MI_{interval}_FromBaseline'] = np.nan  # Placeholder if column missing

diff_cols = [f'MI_{interval}_FromBaseline' for interval in intervals[1:] if f'MI_{interval}_FromBaseline' in df.columns]

# Check if trade_entries has rows; if empty, use full df or warn
if 'trade_entries' not in globals() or trade_entries.empty:
    print("No trade entries found; using full DF for MI diffs.")
    trade_entries = df.copy()  # Fallback to full DF

# At trade entries, show MI diffs (select only existing columns)
existing_diff_cols = [col for col in diff_cols if col in trade_entries.columns]
entry_mi = trade_entries[['Timestamp', 'Twitter_acc', 'Tweet_clean', 'cumulative_oil_accounts'] + existing_diff_cols]

print("MI Diffs at Trade Entries:")
display(entry_mi)
# Out:
# MI Diffs at Trade Entries:
#               Timestamp      Twitter_acc  \
# 42  2025-06-12 19:54:00   Yemenimilitary
# 47  2025-06-12 20:48:00           chigrl
# 62  2025-06-12 23:14:00       WhiteHouse
# 68  2025-06-13 00:07:00        IntelDoge
# 72  2025-06-13 00:20:00  TrumpDailyPosts
# 75  2025-06-13 00:21:00           chigrl
# 76  2025-06-13 00:22:00       WhiteHouse
# 77  2025-06-13 00:22:00            POTUS
# 78  2025-06-13 00:25:00        IntelDoge
# 82  2025-06-13 00:44:00           chigrl
# 84  2025-06-13 00:45:00        IntelDoge
# 85  2025-06-13 00:46:00        IntelDoge
# 90  2025-06-13 01:00:00              IDF
# 91  2025-06-13 01:00:00       WhiteHouse
# 92  2025-06-13 01:00:00            POTUS
# 96  2025-06-13 01:05:00        IsraeliPM
# 99  2025-06-13 01:17:00        IntelDoge
# 101 2025-06-13 01:19:00     SStapczynski
# 104 2025-06-13 01:41:00        IntelDoge
# 105 2025-06-13 01:42:00        IntelDoge
# 114 2025-06-13 02:06:00        IntelDoge
# 116 2025-06-13 02:07:00        IntelDoge
# 124 2025-06-13 02:26:00     SStapczynski
# 125 2025-06-13 02:27:00        IntelDoge
# 126 2025-06-13 02:31:00        IntelDoge
# 128 2025-06-13 02:36:00        IntelDoge
# 132 2025-06-13 02:40:00     SStapczynski
# 136 2025-06-13 02:50:00     SStapczynski
# 137 2025-06-13 02:51:00        IntelDoge
# 138 2025-06-13 02:52:00        IntelDoge
# 139 2025-06-13 02:56:00        IntelDoge
# 140 2025-06-13 02:58:00  IRIran_Military
# 141 2025-06-13 03:00:00        IntelDoge
# 142 2025-06-13 03:00:00  IRIran_Military
# 143 2025-06-13 03:01:00        IntelDoge
# 146 2025-06-13 03:05:00        IntelDoge
# 148 2025-06-13 03:11:00  IRIran_Military
# 152 2025-06-13 03:23:00  IRIran_Military
# 157 2025-06-13 03:32:00        IntelDoge
# 159 2025-06-13 03:37:00  TrumpDailyPosts
# 160 2025-06-13 03:41:00              IDF
# 161 2025-06-13 03:41:00        IntelDoge
#
#                                            Tweet_clean  \
# 42   In an article by the editor-in-chief of Haaret...
# 47   If you missed Catherine Yoshimoto from\n@FTSER...
# 62   President Trump and the First Lady Participate...
# 68   #Israel's Minister of Defense, Israel Katz, ha...
# 72           President Trump News Community - BREAKING
# 75              WTI hits 72.30 on @#$@ is getting real
# 76   AMERICA FIRST — Chants of ‘USA’ rang out loud ...
# 77   AMERICA FIRST — Chants of ‘USA’ rang out loud ...
# 78   Trump convening cabinet level meeting shortly,...
# 82   Not saying you should pay any attention to Nin...
# 84   Israel warning of potential incoming ballistic...
# 85   BREAKING: #IDF confirms preemptive airstrikes ...
# 90   A statement from IDF Spokesperson BG Effie Def...
# 91   Statement from Secretary of State Marco Rubio\...
# 92   Statement from Secretary of State Marco Rubio\...
# 96   Prime Minister Netanyahu:\n"Moments ago, Israe...
# 99   Rumors circulating that the house of Fereydoon...
# 101  Brent oil surges above 8% after Israel carries...
# 104       Iranian air force jets spotted over #Tehran.
# 105  Iran's air force will not be partaking in reta...
# 114  Donald Trump to hold a meeting in the situatio...
# 116  Iranian state TV says "no signs of contaminati...
# 124  Brent oil futures now up more than 9% after Is...
# 125  #Israel'i source to Fox News, "This is just th...
# 126  New target assassination claim.\n\nIn Iran, it...
# 128  In case it is not painfully obvious, I would n...
# 132                 BRENT OIL BRIEFLY UP MORE THAN 13%
# 136  Oil futures are at the highest level since Jan...
# 137  #Israel'i airliners flying empty planes out of...
# 138  Israel pushing HARD that they fully cooperated...
# 139  Iranian air defenses activated in Tehran. New ...
# 140  Zionist terrorists have massacred civilians in...
# 141  As others have mentioned, it absolutely feels ...
# 142  The spokesperson for the Armed Forces’ General...
# 143  Areas around the oil refinery in Tabriz have b...
# 146  Statement out from #Iran's Supreme Leader Ali ...
# 148  An important message from the Leader of the Is...
# 152  In the Name of God, the Compassionate, the Mer...
# 157  The "Wings of Zion", a Boeing 767-338ER respon...
# 159          President Trump News Community - BREAKING
# 160  𝗗𝗘𝗖𝗟𝗔𝗦𝗦𝗜𝗙𝗜𝗘𝗗: 𝗜𝗿𝗮𝗻’𝘀 𝗡𝘂𝗰𝗹𝗲𝗮𝗿 𝗣𝗹𝗮𝗻𝘀\n\nRecent i...
# 161  Wings of Zion aircraft now circling off the co...
#
#      cumulative_oil_accounts
# 42                         5
# 47                         6
# 62                         6
# 68                         7
# 72                         7
# 75                         7
# 76                         7
# 77                         8
# 78                         8
# 82                         8
# 84                         8
# 85                         5
# 90                         9
# 91                         6
# 92                         7
# 96                         9
# 99                         9
# 101                       10
# 104                        7
# 105                       10
# 114                       10
# 116                       10
# 124                       10
# 125                       10
# 126                        7
# 128                        7
# 132                        8
# 136                       10
# 137                       10
# 138                       10
# 139                        8
# 140                        9
# 141                       10
# 142                        9
# 143                       10
# 146                        9
# 148                        9
# 152                        9
# 157                       10
# 159                       10
# 160                        9
# 161                       10
